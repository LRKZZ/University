# %%
import pandas as pd

# %% [markdown]
# 1. Создайте датафрейм с следующими данными:

# %%
df = pd.DataFrame({'Name': ['Strom, Mrs. Wilhelm (Elna Matilda Persson)',
                            'Navratil, Mr. Michel ("Louis M Hoffman")', 'Minahan, Miss. Daisy E'],
                            'Age': [29,5, 33],'Sex':['female','male','female']})
df = df.rename(columns=str.lower)
df
# Out:
#                                          name  age     sex
# 0  Strom, Mrs. Wilhelm (Elna Matilda Persson)   29  female
# 1    Navratil, Mr. Michel ("Louis M Hoffman")    5    male
# 2                      Minahan, Miss. Daisy E   33  female

# %% [markdown]
# 2. Загрузите данные из файла:
# https://drive.google.com/file/d/16gikf9vvMLyldkdHtoDYrPDbqTHP1BxG/view?usp=share_link

# %%
data2=pd.read_csv('titanic_csv.csv', sep=';')
data2
# Out:
#      PassengerId  Survived  Pclass                                  Name  \
# 0            454         1       1              Goldenberg, Mr. Samuel L
# 1            234         1       3        Asplund, Miss. Lillian Gertrud
# 2            556         0       1                    Wright, Mr. George
# 3            766         1       1  Hogeboom, Mrs. John C (Anna Andrews)
# 4            444         1       2             Reynaldo, Ms. Encarnacion
# ..           ...       ...     ...                                   ...
# 489          363         0       3       Barbara, Mrs. (Catherine David)
# 490          447         1       2     Mellinger, Miss. Madeleine Violet
# 491           95         0       3                     Coxon, Mr. Daniel
# 492           59         1       2          West, Miss. Constance Mirium
# 493           33         1       3              Glynn, Miss. Mary Agatha
#
#         Sex   Age  SibSp  Parch      Ticket     Fare Cabin Embarked
# ...

# %% [markdown]
# 3. Загрузите напрямую данные по ссылке:
# https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt (read_csv).

# %%
data1=pd.read_csv('https://gist.githubusercontent.com/zaryanezrya/8b4ef51c707cb16d5e88a44dc00a1bb2/raw/41230f49c6268e072dbf102672f670be256922ab/gistfile1.txt',sep=',')
data1
# Out:
#      passengerid  survived  pclass  \
# 0            552         0       2
# 1            689         0       3
# 2            605         1       1
# 3            305         0       3
# 4            290         1       3
# ..           ...       ...     ...
# 495          482         0       2
# 496          155         0       3
# 497          851         0       3
# 498          850         1       1
# 499           77         0       3
#
#                                              name     sex   age  sibsp  parch  \
# 0                     Sharp, Mr. Percival James R    male  27.0      0      0
# 1                 Fischer, Mr. Eberhard Thelander    male  18.0      0      0
# 2                 Homer, Mr. Harry ("Mr E Haven")    male  35.0      0      0
# 3               Williams, Mr. Howard Hugh "Harry"    male   NaN      0      0
# 4                            Connolly, Miss. Kate  female  22.0      0      0
# ...

# %% [markdown]
# 4. Объедините датафреймы из п. 2, 3 в один датафрейм, удалите дубликаты
# строк.

# %%
# уберем большие буквы, заменив их на маленькие в столбцах
data1=data1.rename(columns=str.lower)
data2=data2.rename(columns=str.lower)

# %%
# объединим в один датафрейм
data=pd.concat([data1,data2])
data
# Out:
#      passengerid  survived  pclass                               name     sex  \
# 0            552         0       2        Sharp, Mr. Percival James R    male
# 1            689         0       3    Fischer, Mr. Eberhard Thelander    male
# 2            605         1       1    Homer, Mr. Harry ("Mr E Haven")    male
# 3            305         0       3  Williams, Mr. Howard Hugh "Harry"    male
# 4            290         1       3               Connolly, Miss. Kate  female
# ..           ...       ...     ...                                ...     ...
# 489          363         0       3    Barbara, Mrs. (Catherine David)  female
# 490          447         1       2  Mellinger, Miss. Madeleine Violet  female
# 491           95         0       3                  Coxon, Mr. Daniel    male
# 492           59         1       2       West, Miss. Constance Mirium  female
# 493           33         1       3           Glynn, Miss. Mary Agatha  female
#
# ...

# %%
# уберем дубликаты
data=data.drop_duplicates()
data
# Out:
#      passengerid  survived  pclass                               name     sex  \
# 0            552         0       2        Sharp, Mr. Percival James R    male
# 1            689         0       3    Fischer, Mr. Eberhard Thelander    male
# 2            605         1       1    Homer, Mr. Harry ("Mr E Haven")    male
# 3            305         0       3  Williams, Mr. Howard Hugh "Harry"    male
# 4            290         1       3               Connolly, Miss. Kate  female
# ..           ...       ...     ...                                ...     ...
# 489          363         0       3    Barbara, Mrs. (Catherine David)  female
# 490          447         1       2  Mellinger, Miss. Madeleine Violet  female
# 491           95         0       3                  Coxon, Mr. Daniel    male
# 492           59         1       2       West, Miss. Constance Mirium  female
# 493           33         1       3           Glynn, Miss. Mary Agatha  female
#
# ...

# %% [markdown]
# 5. Задайте в качестве индекса датафрейма id пассажира. Отсортируйте по
# индексу (sort_values).

# %%
data=data.set_index('passengerid') # делаем passengerid не столбцом, а индексом
data.sort_values(by=['passengerid']) # сортируем по возрастанию
# Out:
#              survived  pclass  \
# passengerid
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           name     sex   age  \
# passengerid
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# 6. Отобразите информацию и базовую статистику по датафрейму (info, describe)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 891 entries, 552 to 33
# Data columns (total 11 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   survived  891 non-null    int64
#  1   pclass    891 non-null    int64
#  2   name      891 non-null    object
#  3   sex       891 non-null    object
#  4   age       714 non-null    float64
#  5   sibsp     891 non-null    int64
#  6   parch     891 non-null    int64
#  7   ticket    891 non-null    object
#  8   fare      891 non-null    float64
#  9   cabin     204 non-null    object
#  10  embarked  889 non-null    object
# dtypes: float64(2), int64(4), object(5)
# memory usage: 83.5+ KB

# %%
data.describe()
# Out:
#          survived      pclass         age       sibsp       parch        fare
# count  891.000000  891.000000  714.000000  891.000000  891.000000  891.000000
# mean     0.383838    2.308642   29.699118    0.523008    0.381594   32.204208
# std      0.486592    0.836071   14.526497    1.102743    0.806057   49.693429
# min      0.000000    1.000000    0.420000    0.000000    0.000000    0.000000
# 25%      0.000000    2.000000   20.125000    0.000000    0.000000    7.910400
# 50%      0.000000    3.000000   28.000000    0.000000    0.000000   14.454200
# 75%      1.000000    3.000000   38.000000    1.000000    0.000000   31.000000
# max      1.000000    3.000000   80.000000    8.000000    6.000000  512.329200

# %% [markdown]
# 7. Поменяйте местами нулевую по порядку строку с элементом с индексом 2 (loc,
# iloc).

# %%
tmp=data.iloc[0]
data.iloc[0]=data.loc[2]
data.loc[2]=tmp
data.iloc[0]
# Out:
# survived                                                    1
# pclass                                                      1
# name        Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                    female
# age                                                      38.0
# sibsp                                                       1
# parch                                                       0
# ticket                                               PC 17599
# fare                                                  71.2833
# cabin                                                     C85
# embarked                                                    C
# Name: 552, dtype: object

# %% [markdown]
# 8. В столбце Sex замените female/male на f/m (map).

# %%
data['sex'] = data['sex'].replace({'female': 'f', 'male': 'm'})
data
# Out:
#              survived  pclass  \
# passengerid
# 552                 1       1
# 689                 0       3
# 605                 1       1
# 305                 0       3
# 290                 1       3
# ...               ...     ...
# 363                 0       3
# 447                 1       2
# 95                  0       3
# 59                  1       2
# 33                  1       3
#
#                                                           name sex   age  \
# passengerid
# 552          Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 689                            Fischer, Mr. Eberhard Thelander   m  18.0
# 605                            Homer, Mr. Harry ("Mr E Haven")   m  35.0
# 305                          Williams, Mr. Howard Hugh "Harry"   m   NaN
# 290                                       Connolly, Miss. Kate   f  22.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# 9. Найдите билеты по которым плыло 6 и более человек, отобразите список людей
# (groupby, count).

# %%
df_check = data.groupby('ticket')['name'].count() # в датафрейм поместим все номера билетов и количество людей, которые числятся за этими билетами
tickets=df_check[df_check>=6] # возьмем только те билеты, где количество людей >= 6
tickets
# Out:
# ticket
# 1601        7
# 3101295     6
# 347082      7
# 347088      6
# CA 2144     6
# CA. 2343    7
# Name: name, dtype: int64

# %%
data[data['ticket'].isin(tickets.index)] #фильтруем датафрейм и оставляем только строки с номерами билетов, которые есть в tickets
# Out:
#              survived  pclass  \
# passengerid
# 60                  0       3
# 611                 0       3
# 325                 0       3
# 181                 0       3
# 864                 0       3
# 825                 0       3
# 814                 0       3
# 51                  0       3
# 827                 0       3
# 165                 0       3
# 635                 0       3
# 202                 0       3
# 64                  0       3
# 684                 0       3
# 687                 0       3
# 267                 0       3
# 14                  0       3
# 693                 1       3
# 361                 0       3
# 643                 0       3
# 510                 1       3
# 851                 0       3
# 160                 0       3
# 820                 0       3
# 168                 0       3
# 481                 0       3
# 847                 0       3
# 543                 0       3
# 72                  0       3
# ...

# %% [markdown]
# 10.Найдите людей, которые плыли в одной каюте с людьми из датафрейма из п1.

# %%
peoples=data[data['name'].isin(df['name'])] #создаем датафрейм together, который будет содержать только те строки, где значения в data['name' ]
                                            #будут совпадать со значениями, которые есть в df['name']
peoples                                     #т.е. мы находим людей из первого df в основном датафрейме.
# Out:
#              survived  pclass                                        name sex  \
# passengerid
# 149                 0       2    Navratil, Mr. Michel ("Louis M Hoffman")   m
# 252                 0       3  Strom, Mrs. Wilhelm (Elna Matilda Persson)   f
# 413                 1       1                      Minahan, Miss. Daisy E   f
#
#               age  sibsp  parch  ticket     fare cabin embarked
# passengerid
# 149          36.5      0      2  230080  26.0000    F2        S
# 252          29.0      1      1  347054  10.4625    G6        S
# 413          33.0      1      0   19928  90.0000   C78        Q

# %%
together = data[data['cabin'].isin(peoples['cabin'])] #создаем DF together, в котором будут только те строки, у которых совпадают 'cabin'
together
# Out:
#              survived  pclass  \
# passengerid
# 194                 1       2
# 206                 0       3
# 149                 0       2
# 246                 0       1
# 395                 1       3
# 252                 0       3
# 341                 1       2
# 11                  1       3
# 413                 1       1
#
#                                                           name sex   age  \
# passengerid
# 194                                 Navratil, Master. Michel M   m   3.0
# 206                                 Strom, Miss. Telma Matilda   f   2.0
# 149                   Navratil, Mr. Michel ("Louis M Hoffman")   m  36.5
# 246                                Minahan, Dr. William Edward   m  44.0
# 395          Sandstrom, Mrs. Hjalmar (Agnes Charlotta Bengt...   f  24.0
# 252                 Strom, Mrs. Wilhelm (Elna Matilda Persson)   f  29.0
# 341                             Navratil, Master. Edmond Roger   m   2.0
# ...

# %% [markdown]
# 11.Добавьте колонку “BirthYear” с годом рождения каждого пассажира.

# %% [markdown]
# Трагедия произошла в 1912 году. Эта информация потребуется, чтобы правильно отобразить год рождения.

# %%
data['birthyear'] = 1912-data['age']
data
# Out:
#              survived  pclass  \
# passengerid
# 552                 1       1
# 689                 0       3
# 605                 1       1
# 305                 0       3
# 290                 1       3
# ...               ...     ...
# 363                 0       3
# 447                 1       2
# 95                  0       3
# 59                  1       2
# 33                  1       3
#
#                                                           name sex   age  \
# passengerid
# 552          Cumings, Mrs. John Bradley (Florence Briggs Th...   f  38.0
# 689                            Fischer, Mr. Eberhard Thelander   m  18.0
# 605                            Homer, Mr. Harry ("Mr E Haven")   m  35.0
# 305                          Williams, Mr. Howard Hugh "Harry"   m   NaN
# 290                                       Connolly, Miss. Kate   f  22.0
# ...                                                        ...  ..   ...
# ...

# %% [markdown]
# 12.Добавьте колонку “Companion” с количеством попутчиков в одной каюте с этим
# пассажиром.

# %%
#сперва сделаем датафрейм, который будет содержать в себе кабины и количество людей, которые были в них
cabins = data.groupby('cabin')['name'].count() #сгруппируем по cabin и выведем количество людей, которые были в них
cabins
# Out:
# cabin
# A10    1
# A14    1
# A16    1
# A19    1
# A20    1
#       ..
# F33    3
# F38    1
# F4     2
# G6     4
# T      1
# Name: name, Length: 147, dtype: int64

# %%
#создаем столбец companion
data['companion'] = data['cabin'].map(cabins) #берем информацию о кабине из cabins, и в companion присваиваем количество людей в этой кабине
data.sort_index()
# Out:
#              survived  pclass                                          name  \
# passengerid
# 1                   0       3                       Braund, Mr. Owen Harris
# 2                   0       2                   Sharp, Mr. Percival James R
# 3                   1       3                        Heikkinen, Miss. Laina
# 4                   1       1  Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 5                   0       3                      Allen, Mr. William Henry
# ...               ...     ...                                           ...
# 887                 0       2                         Montvila, Rev. Juozas
# 888                 1       1                  Graham, Miss. Margaret Edith
# 889                 0       3      Johnston, Miss. Catherine Helen "Carrie"
# 890                 1       1                         Behr, Mr. Karl Howell
# 891                 0       3                           Dooley, Mr. Patrick
#
# ...

# %% [markdown]
# 13.Поменяйте местами нулевую по порядку строку с элементом с индексом 1.

# %%
data.iloc[0]
# Out:
# survived                                                     1
# pclass                                                       1
# name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                          f
# age                                                       38.0
# sibsp                                                        1
# parch                                                        0
# ticket                                                PC 17599
# fare                                                   71.2833
# cabin                                                      C85
# embarked                                                     C
# birthyear                                               1874.0
# companion                                                  1.0
# Name: 552, dtype: object

# %%
data.loc[1]
# Out:
# survived                           0
# pclass                             3
# name         Braund, Mr. Owen Harris
# sex                                m
# age                             22.0
# sibsp                              1
# parch                              0
# ticket                     A/5 21171
# fare                            7.25
# cabin                            NaN
# embarked                           S
# birthyear                     1890.0
# companion                        NaN
# Name: 1, dtype: object

# %%
tmp=data.iloc[0]
data.iloc[0]=data.loc[1]
data.loc[1]=tmp
data.iloc[0]
# Out:
# survived                           0
# pclass                             3
# name         Braund, Mr. Owen Harris
# sex                                m
# age                             22.0
# sibsp                              1
# parch                              0
# ticket                     A/5 21171
# fare                            7.25
# cabin                            NaN
# embarked                           S
# birthyear                     1890.0
# companion                        NaN
# Name: 552, dtype: object

# %%
data.loc[1]
# Out:
# survived                                                     1
# pclass                                                       1
# name         Cumings, Mrs. John Bradley (Florence Briggs Th...
# sex                                                          f
# age                                                       38.0
# sibsp                                                        1
# parch                                                        0
# ticket                                                PC 17599
# fare                                                   71.2833
# cabin                                                      C85
# embarked                                                     C
# birthyear                                               1874.0
# companion                                                  1.0
# Name: 1, dtype: object

# %% [markdown]
# 14.Запишите получившийся датафрейм в csv файл (to_csv).

# %%
data.to_csv('solution14.csv',sep=';')

# %% [markdown]
# 15.Отобразите топ-10 людей, которые больше остальных заплатили за билет.

# %% [markdown]
# За цену билета отвечает столбец fare, поэтому будем сортировать по нему

# %%
data.sort_values(by='fare', ascending=False).head(10) #ascending=False - упорядочиваем в порядке от наибольшего к наименьшему. Если поставить True - то наоборот
# Out:
#              survived  pclass                                   name sex  \
# passengerid
# 738                 1       1                 Lesurer, Mr. Gustave J   m
# 259                 1       1                       Ward, Miss. Anna   f
# 680                 1       1     Cardeza, Mr. Thomas Drake Martinez   m
# 89                  1       1             Fortune, Miss. Mabel Helen   f
# 342                 1       1         Fortune, Miss. Alice Elizabeth   f
# 439                 0       1                      Fortune, Mr. Mark   m
# 28                  0       1         Fortune, Mr. Charles Alexander   m
# 743                 1       1  Ryerson, Miss. Susan Parker "Suzette"   f
# 312                 1       1             Ryerson, Miss. Emily Borie   f
# 119                 0       1               Baxter, Mr. Quigg Edmond   m
#
#               age  sibsp  parch    ticket      fare            cabin embarked  \
# passengerid
# ...

# %% [markdown]
# 16.Отобразите сколько женщин и мужчин выжило/не выжило.

# %%
print(f"Количество людей на корабле: {data.shape[0]}")
# Out:
# Количество людей на корабле: 891

# %%
print(f"Количество выживших на корабле: {data[data['survived']==1].shape[0]}") #среди всех строк учитываем только те, у которых в столбце survived значение равняется 1
# Out:
# Количество выживших на корабле: 342

# %%
print(f"На корабле выжило {data[(data['survived']==1) & (data['sex']=='m')].shape[0]} мужчин") #среди всех строк учитываем только те, у которых выполняются условия survived = 1, sex = m
print(f"На корабле не выжило {data[(data['survived']==0) & (data['sex']=='m')].shape[0]} мужчин")

print(f"На корабле выжило {data[(data['survived']==1) & (data['sex']=='f')].shape[0]} женщин" )
print(f"На корабле не выжило {data[(data['survived']==0) & (data['sex']=='f')].shape[0]} женщин")
# Out:
# На корабле выжило 109 мужчин
# На корабле не выжило 468 мужчин
# На корабле выжило 233 женщин
# На корабле не выжило 81 женщин

# %% [markdown]
# 17.Отобразите сколько в каком классе пассажиров выжило/не выжило.

# %% [markdown]
# За класс отвечает столбец pclass. Будем сортировать по нему.

# %%
# посчитаем количество выживших людей в каждом классе (заодно узнаем количество классов)
df_class = data.groupby('pclass')['survived'].count()
df_class
# Out:
# pclass
# 1    216
# 2    184
# 3    491
# Name: survived, dtype: int64

# %%
print(f"В первом классе выжило {data[(data['survived']==1) & (data['pclass']==1)].shape[0]} пассажиров")
print(f"В первом классе не выжило {data[(data['survived']==0) & (data['pclass']==1)].shape[0]} пассажиров")
print()
print(f"Во втором классе выжило {data[(data['survived']==1) & (data['pclass']==2)].shape[0]} пассажиров")
print(f"Во втором классе не выжило {data[(data['survived']==0) & (data['pclass']==2)].shape[0]} пассажиров")
print()
print(f"В третьем классе выжило {data[(data['survived']==1) & (data['pclass']==3)].shape[0]} пассажиров")
print(f"В третьем классе не выжило {data[(data['survived']==0) & (data['pclass']==3)].shape[0]} пассажиров")
# Out:
# В первом классе выжило 136 пассажиров
# В первом классе не выжило 80 пассажиров
#
# Во втором классе выжило 87 пассажиров
# Во втором классе не выжило 97 пассажиров
#
# В третьем классе выжило 119 пассажиров
# В третьем классе не выжило 372 пассажиров
